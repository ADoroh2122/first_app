# %%
import requests
import pandas as pd

# %%
d1=pd.read_csv(r"C:\Users\adoro\OneDrive\Documents\GitHub\first_app\student+performance\student\student-mat.csv", sep=";", header= None)
d1
# Out:
#          0    1    2        3        4        5     6     7         8   \
# 0    school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob
# 1        GP    F   18        U      GT3        A     4     4   at_home
# 2        GP    F   17        U      GT3        T     1     1   at_home
# 3        GP    F   15        U      LE3        T     1     1   at_home
# 4        GP    F   15        U      GT3        T     4     2    health
# ..      ...  ...  ...      ...      ...      ...   ...   ...       ...
# 391      MS    M   20        U      LE3        A     2     2  services
# 392      MS    M   17        U      LE3        T     3     1  services
# 393      MS    M   21        R      GT3        T     1     1     other
# 394      MS    M   18        R      LE3        T     3     2  services
# 395      MS    M   19        U      LE3        T     1     1     other
#
#            9   ...      23        24     25    26    27      28        29  30  \
# 0        Fjob  ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1
# 1     teacher  ...       4         3      4     1     1       3         6   5
# 2       other  ...       5         3      3     1     1       3         4   5
# 3       other  ...       4         3      2     2     3       3        10   7
# 4    services  ...       3         2      2     1     1       5         2  15
# ..        ...  ...     ...       ...    ...   ...   ...     ...       ...  ..
# 391  services  ...       5         5      4     4     5       4        11   9
# 392  services  ...       2         4      5     3     4       2         3  14
# 393     other  ...       5         5      3     3     3       3         3  10
# 394     other  ...       4         4      1     3     4       5         0  11
# 395   at_home  ...       3         2      3     3     3       5         5   8
#
#      31  32
# 0    G2  G3
# 1     6   6
# 2     5   6
# 3     8  10
# 4    14  15
# ..   ..  ..
# 391   9   9
# 392  16  16
# 393   8   7
# 394  12  10
# 395   9   9
#
# [396 rows x 33 columns]

# %%
d1.columns = d1.iloc[0]
d1.columns
d1 = d1.drop(index=0)
d1
# Out:
# 0   school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 1       GP   F  18       U     GT3       A    4    4   at_home   teacher  ...
# 2       GP   F  17       U     GT3       T    1    1   at_home     other  ...
# 3       GP   F  15       U     LE3       T    1    1   at_home     other  ...
# 4       GP   F  15       U     GT3       T    4    2    health  services  ...
# 5       GP   F  16       U     GT3       T    3    3     other     other  ...
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...  ...
# 391     MS   M  20       U     LE3       A    2    2  services  services  ...
# 392     MS   M  17       U     LE3       T    3    1  services  services  ...
# 393     MS   M  21       R     GT3       T    1    1     other     other  ...
# 394     MS   M  18       R     LE3       T    3    2  services     other  ...
# 395     MS   M  19       U     LE3       T    1    1     other   at_home  ...
#
# 0   famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 1        4        3     4    1    1      3        6   5   6   6
# 2        5        3     3    1    1      3        4   5   5   6
# 3        4        3     2    2    3      3       10   7   8  10
# 4        3        2     2    1    1      5        2  15  14  15
# 5        4        3     2    1    2      5        4   6  10  10
# ..     ...      ...   ...  ...  ...    ...      ...  ..  ..  ..
# 391      5        5     4    4    5      4       11   9   9   9
# 392      2        4     5    3    4      2        3  14  16  16
# 393      5        5     3    3    3      3        3  10   8   7
# 394      4        4     1    3    4      5        0  11  12  10
# 395      3        2     3    3    3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
d1.columns = d1.columns.str.lower().str.strip().str.replace(' ', '_')
d1.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object', name=0)

# %%
d1 = d1.reset_index()
d1
# Out:
# 0    index school sex age address famsize pstatus medu fedu      mjob  ...  \
# 0        1     GP   F  18       U     GT3       A    4    4   at_home  ...
# 1        2     GP   F  17       U     GT3       T    1    1   at_home  ...
# 2        3     GP   F  15       U     LE3       T    1    1   at_home  ...
# 3        4     GP   F  15       U     GT3       T    4    2    health  ...
# 4        5     GP   F  16       U     GT3       T    3    3     other  ...
# ..     ...    ...  ..  ..     ...     ...     ...  ...  ...       ...  ...
# 390    391     MS   M  20       U     LE3       A    2    2  services  ...
# 391    392     MS   M  17       U     LE3       T    3    1  services  ...
# 392    393     MS   M  21       R     GT3       T    1    1     other  ...
# 393    394     MS   M  18       R     LE3       T    3    2  services  ...
# 394    395     MS   M  19       U     LE3       T    1    1     other  ...
#
# 0   famrel freetime goout dalc walc health absences  g1  g2  g3
# 0        4        3     4    1    1      3        6   5   6   6
# 1        5        3     3    1    1      3        4   5   5   6
# 2        4        3     2    2    3      3       10   7   8  10
# 3        3        2     2    1    1      5        2  15  14  15
# 4        4        3     2    1    2      5        4   6  10  10
# ..     ...      ...   ...  ...  ...    ...      ...  ..  ..  ..
# 390      5        5     4    4    5      4       11   9   9   9
# 391      2        4     5    3    4      2        3  14  16  16
# 392      5        5     3    3    3      3        3  10   8   7
# 393      4        4     1    3    4      5        0  11  12  10
# 394      3        2     3    3    3      5        5   8   9   9
#
# [395 rows x 34 columns]

# %%
d2=pd.read_csv(r"C:\Users\adoro\OneDrive\Documents\GitHub\first_app\student+performance\student\student-por.csv", sep=";", header= None)
d2
# Out:
#          0    1    2        3        4        5     6     7         8   \
# 0    school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob
# 1        GP    F   18        U      GT3        A     4     4   at_home
# 2        GP    F   17        U      GT3        T     1     1   at_home
# 3        GP    F   15        U      LE3        T     1     1   at_home
# 4        GP    F   15        U      GT3        T     4     2    health
# ..      ...  ...  ...      ...      ...      ...   ...   ...       ...
# 645      MS    F   19        R      GT3        T     2     3  services
# 646      MS    F   18        U      LE3        T     3     1   teacher
# 647      MS    F   18        U      GT3        T     1     1     other
# 648      MS    M   17        U      LE3        T     3     1  services
# 649      MS    M   18        R      LE3        T     3     2  services
#
#            9   ...      23        24     25    26    27      28        29  30  \
# 0        Fjob  ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1
# 1     teacher  ...       4         3      4     1     1       3         4   0
# 2       other  ...       5         3      3     1     1       3         2   9
# 3       other  ...       4         3      2     2     3       3         6  12
# 4    services  ...       3         2      2     1     1       5         0  14
# ..        ...  ...     ...       ...    ...   ...   ...     ...       ...  ..
# 645     other  ...       5         4      2     1     2       5         4  10
# 646  services  ...       4         3      4     1     1       1         4  15
# 647     other  ...       1         1      1     1     1       5         6  11
# 648  services  ...       2         4      5     3     4       2         6  10
# 649     other  ...       4         4      1     3     4       5         4  10
#
#      31  32
# 0    G2  G3
# 1    11  11
# 2    11  11
# 3    13  12
# 4    14  14
# ..   ..  ..
# 645  11  10
# 646  15  16
# 647  12   9
# 648  10  10
# 649  11  11
#
# [650 rows x 33 columns]

# %%
d2.columns = d2.iloc[0]
d2.columns
d2= d2.drop(index=0)
d2
# Out:
# 0   school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 1       GP   F  18       U     GT3       A    4    4   at_home   teacher  ...
# 2       GP   F  17       U     GT3       T    1    1   at_home     other  ...
# 3       GP   F  15       U     LE3       T    1    1   at_home     other  ...
# 4       GP   F  15       U     GT3       T    4    2    health  services  ...
# 5       GP   F  16       U     GT3       T    3    3     other     other  ...
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...  ...
# 645     MS   F  19       R     GT3       T    2    3  services     other  ...
# 646     MS   F  18       U     LE3       T    3    1   teacher  services  ...
# 647     MS   F  18       U     GT3       T    1    1     other     other  ...
# 648     MS   M  17       U     LE3       T    3    1  services  services  ...
# 649     MS   M  18       R     LE3       T    3    2  services     other  ...
#
# 0   famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 1        4        3     4    1    1      3        4   0  11  11
# 2        5        3     3    1    1      3        2   9  11  11
# 3        4        3     2    2    3      3        6  12  13  12
# 4        3        2     2    1    1      5        0  14  14  14
# 5        4        3     2    1    2      5        0  11  13  13
# ..     ...      ...   ...  ...  ...    ...      ...  ..  ..  ..
# 645      5        4     2    1    2      5        4  10  11  10
# 646      4        3     4    1    1      1        4  15  15  16
# 647      1        1     1    1    1      5        6  11  12   9
# 648      2        4     5    3    4      2        6  10  10  10
# 649      4        4     1    3    4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
d2.columns = d2.columns.str.lower().str.strip().str.replace(' ', '_')
d2.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object', name=0)

# %%
d2 = d2.reset_index()
d2
# Out:
# 0    index school sex age address famsize pstatus medu fedu      mjob  ...  \
# 0        1     GP   F  18       U     GT3       A    4    4   at_home  ...
# 1        2     GP   F  17       U     GT3       T    1    1   at_home  ...
# 2        3     GP   F  15       U     LE3       T    1    1   at_home  ...
# 3        4     GP   F  15       U     GT3       T    4    2    health  ...
# 4        5     GP   F  16       U     GT3       T    3    3     other  ...
# ..     ...    ...  ..  ..     ...     ...     ...  ...  ...       ...  ...
# 644    645     MS   F  19       R     GT3       T    2    3  services  ...
# 645    646     MS   F  18       U     LE3       T    3    1   teacher  ...
# 646    647     MS   F  18       U     GT3       T    1    1     other  ...
# 647    648     MS   M  17       U     LE3       T    3    1  services  ...
# 648    649     MS   M  18       R     LE3       T    3    2  services  ...
#
# 0   famrel freetime goout dalc walc health absences  g1  g2  g3
# 0        4        3     4    1    1      3        4   0  11  11
# 1        5        3     3    1    1      3        2   9  11  11
# 2        4        3     2    2    3      3        6  12  13  12
# 3        3        2     2    1    1      5        0  14  14  14
# 4        4        3     2    1    2      5        0  11  13  13
# ..     ...      ...   ...  ...  ...    ...      ...  ..  ..  ..
# 644      5        4     2    1    2      5        4  10  11  10
# 645      4        3     4    1    1      1        4  15  15  16
# 646      1        1     1    1    1      5        6  11  12   9
# 647      2        4     5    3    4      2        6  10  10  10
# 648      4        4     1    3    4      5        4  10  11  11
#
# [649 rows x 34 columns]

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       649 non-null    int64
#  1   school      649 non-null    object
#  2   sex         649 non-null    object
#  3   age         649 non-null    object
#  4   address     649 non-null    object
#  5   famsize     649 non-null    object
#  6   pstatus     649 non-null    object
#  7   medu        649 non-null    object
#  8   fedu        649 non-null    object
#  9   mjob        649 non-null    object
#  10  fjob        649 non-null    object
#  11  reason      649 non-null    object
#  12  guardian    649 non-null    object
#  13  traveltime  649 non-null    object
#  14  studytime   649 non-null    object
#  15  failures    649 non-null    object
#  16  schoolsup   649 non-null    object
#  17  famsup      649 non-null    object
#  18  paid        649 non-null    object
#  19  activities  649 non-null    object
#  20  nursery     649 non-null    object
#  21  higher      649 non-null    object
#  22  internet    649 non-null    object
#  23  romantic    649 non-null    object
#  24  famrel      649 non-null    object
#  25  freetime    649 non-null    object
#  26  goout       649 non-null    object
#  27  dalc        649 non-null    object
#  28  walc        649 non-null    object
#  29  health      649 non-null    object
#  30  absences    649 non-null    object
#  31  g1          649 non-null    object
#  32  g2          649 non-null    object
#  33  g3          649 non-null    object
# dtypes: int64(1), object(33)
# memory usage: 172.5+ KB

# %%
d1['age'] = d1['age'].astype(int)

# %%
d1['medu'] = d1['medu'].astype(int)

# %%
d1['fedu'] = d1['fedu'].astype(int)

# %%
d1['traveltime'] = d1['traveltime'].astype(int)

# %%
d1['studytime'] = d1['studytime'].astype(int)

# %%
d1['failures'] = d1['failures'].astype(int)

# %%
d1['schoolsup'] = d1['schoolsup'].astype(bool)

# %%
d1['famsup'] = d1['famsup'].astype(bool)

# %%
d1['paid'] = d1['paid'].astype(bool)

# %%
d1['activities'] = d1['activities'].astype(bool)

# %%
d1['nursery'] = d1['nursery'].astype(bool)

# %%
d1['higher'] = d1['higher'].astype(bool)

# %%
d1['internet'] = d1['internet'].astype(bool)

# %%
d1['romantic'] = d1['romantic'].astype(bool)

# %%
d1['famrel'] = d1['famrel'].astype(int)

# %%
d1['freetime'] = d1['freetime'].astype(int)

# %%
d1['goout'] = d1['goout'].astype(int)

# %%
d1['dalc'] = d1['dalc'].astype(int)

# %%
d1['walc'] = d1['walc'].astype(int)

# %%
d1['health'] = d1['health'].astype(int)

# %%
d1['absences'] = d1['absences'].astype(int)

# %%
d1['g1'] = d1['g1'].astype(int)

# %%
d1['g2'] = d1['g2'].astype(int)

# %%
d1['g3'] = d1['g3'].astype(int)

# %%
con_str = 'mongodb+srv://andrew:codingtemple@lancers.ureqiwj.mongodb.net/?retryWrites=true&w=majority'

import pymongo

client = pymongo.MongoClient(con_str)

# %%
# Create databases
db = client.db

# Create a collection from the database
student = db.student
classmate = db.classmate

# %%
# Set the dataframe index to the id column:
d1.set_index('index', inplace = True)
d2.set_index('index', inplace = True)

# %%
student.insert_many(d1.to_dict(orient='records'))

# %%
classmate.insert_many(d2.to_dict(orient='records'))
